# %%
# importing the necessary packages
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# %%
newsrooms = pd.read_csv('../data/newsrooms.csv')
newsrooms.columns = ['site', 'monthly_visits', 'country', 'country_of_pub']
newsrooms.dropna(inplace=True)
newsrooms = newsrooms.drop_duplicates(subset = 'site')
newsrooms = newsrooms.sort_values(by=['country_of_pub', 'monthly_visits'], ascending=False).reset_index().drop('index', axis=1)

# %%
# set dfs with sites
UK = newsrooms[newsrooms['country_of_pub']=='UK'].reset_index().drop('index', axis=1)
USA = newsrooms[newsrooms['country_of_pub']=='USA'].reset_index().drop('index', axis=1)
India = newsrooms[newsrooms['country_of_pub']=='India'].reset_index().drop('index', axis=1)
SA = newsrooms[newsrooms['country_of_pub']=='South Africa'].reset_index().drop('index', axis=1)

# %%
from requests import get
from bs4 import BeautifulSoup
from time import sleep
import re
from random import randint #avoid throttling by not sending too many requests one after the other
from warnings import warn
from time import time
from IPython.core.display import clear_output
import numpy as np
import datetime

# %%
def send_request(url):
    '''Send request and sleep if a connection error comes up.'''
    # send request
    try:
        r1 = requests.get(url)
    except (ConnectionError, OSError, TimeoutError) as e:
        print("Encountered an error, F*** YOU GOOGLE, sleeping . . .")
        sleep(90)
        try:
            r1 = requests.get(url)
        except (ConnectionError, OSError, TimeoutError) as e:
            print("Encountered an error, F*** YOU GOOGLE, sleeping . . .")
            sleep(90)
            try:
                r1 = requests.get(url)
            except (ConnectionError, OSError, TimeoutError) as e:
                print("Encountered an error, F*** YOU GOOGLE, sleeping . . .")
                sleep(90)
                r1 = requests.get(url)
    # get html content
    coverpage = r1.content
    soup1 = BeautifulSoup(coverpage, 'html5lib')
    
    return soup1

# %%
# loop
# %time
from time import sleep
from random import randint
# Country: 
query = ['women | woman | girl | girls | female | females | lady | ladies | she | her']
# sites = list(USA.site.unique().flatten())[10:12]
sites = list(SA.site.unique().flatten())[12:]
starting_result = range(0, 310, 10)
# starting_result = [0, 10]


for site in sites:
    
    urls = []
    headlines = []
    subtitles = []
    times = []
    scrape_dates = []
    websites = []
    
    for start in starting_result:
        # keep track
        print("Scraping page", str((start+10)/10), "of", site, "google news results.")
        # change url
        url = f'https://www.google.com/search?q={query[0]}+site:{site}&tbm=nws&sxsrf=ALeKk02yZ8PpgaqZrEk_lf2SjYFoIO2UFA:1605438024548&ei=SAqxX9v1IIv0kwXI44gY&start={start}&sa=N&ved=0ahUKEwjbuaXZsoTtAhUL-qQKHcgxAgM4FBDy0wMIhgE&biw=1188&bih=962&dpr=1.25'
        # sleep
        sleep(randint(10,60))
#         # send request
#         try:
#             r1 = requests.get(url)
#         except ConnectionError:
#             sleep(90)
#             r1 = requests.get(url)
#         # get html content
#         coverpage = r1.content
#         soup1 = BeautifulSoup(coverpage, 'html5lib')
        soup1 = send_request(url)
        # check whether google is trying to redirect to captcha
        if "Our systems have detected unusual traffic from your computer network" in str(soup1):
            sleep(90)
            soup1 = send_request(url)
        # continue
        coverpage_news = soup1.find_all('div', class_='ZINbbc xpd O9g5cc uUPGi')
        if len(coverpage_news)>0:
            # get info for each of 10 google results
            for i in range(len(coverpage_news)):
                # url
                url = coverpage_news[i].a['href'][7:]
                urls.append(url)
                # headline
                headline = coverpage_news[i].a.text
                headlines.append(headline)
                # subtitle
                subtitle = coverpage_news[i].text.split('�')[1].strip().strip('"').strip('.')
                subtitles.append(subtitle)
                # time
                time = coverpage_news[i].span.text
                times.append(time)
                # scrape date
                scrape_date = datetime.datetime.now().strftime("%d/%m/%Y")
                scrape_dates.append(scrape_date)
                # website
                websites.append(site)
            # keep track
            print(str(start + 10) + " results of site " + str(site) + " scraped successfully!")
        else:
            break
            
    # dictionary of results
    headlines_dict = {"url": urls, "headline": headlines,  "subtitle": subtitles, "time": times, "scrape_date": scrape_dates, "site": websites}
    # df of results
    headlines_df = pd.DataFrame.from_dict(headlines_dict)
    number_of_articles = len(headlines_df)
    # save results to csv
    headlines_df.to_csv(f'../data/{number_of_articles}_{site}_articles.csv')
    # print final statement
    print("Saved data from " + str(number_of_articles) + " articles of "  + str(site) + " to .csv!")
    
print("Scrape complete!")
# Out:
# Wall time: 0 ns
# Scraping page 1.0 of Dailymaverick.co.za google news results.
# 10 results of site Dailymaverick.co.za scraped successfully!
# Scraping page 2.0 of Dailymaverick.co.za google news results.
# 20 results of site Dailymaverick.co.za scraped successfully!
# Scraping page 3.0 of Dailymaverick.co.za google news results.
# 30 results of site Dailymaverick.co.za scraped successfully!
# Scraping page 4.0 of Dailymaverick.co.za google news results.
# 40 results of site Dailymaverick.co.za scraped successfully!
# Scraping page 5.0 of Dailymaverick.co.za google news results.
# 50 results of site Dailymaverick.co.za scraped successfully!
# Scraping page 6.0 of Dailymaverick.co.za google news results.
# 60 results of site Dailymaverick.co.za scraped successfully!
# Scraping page 7.0 of Dailymaverick.co.za google news results.
# 70 results of site Dailymaverick.co.za scraped successfully!
# Scraping page 8.0 of Dailymaverick.co.za google news results.
# 80 results of site Dailymaverick.co.za scraped successfully!
# Scraping page 9.0 of Dailymaverick.co.za google news results.
# 90 results of site Dailymaverick.co.za scraped successfully!
# Scraping page 10.0 of Dailymaverick.co.za google news results.
# 100 results of site Dailymaverick.co.za scraped successfully!
# Scraping page 11.0 of Dailymaverick.co.za google news results.
# 110 results of site Dailymaverick.co.za scraped successfully!
# Scraping page 12.0 of Dailymaverick.co.za google news results.
# 120 results of site Dailymaverick.co.za scraped successfully!
# Scraping page 13.0 of Dailymaverick.co.za google news results.
# 130 results of site Dailymaverick.co.za scraped successfully!
# Scraping page 14.0 of Dailymaverick.co.za google news results.
# 140 results of site Dailymaverick.co.za scraped successfully!
# Scraping page 15.0 of Dailymaverick.co.za google news results.
# 150 results of site Dailymaverick.co.za scraped successfully!
# Scraping page 16.0 of Dailymaverick.co.za google news results.
# 160 results of site Dailymaverick.co.za scraped successfully!
# Scraping page 17.0 of Dailymaverick.co.za google news results.
# 170 results of site Dailymaverick.co.za scraped successfully!
# Scraping page 18.0 of Dailymaverick.co.za google news results.
# 180 results of site Dailymaverick.co.za scraped successfully!
# Scraping page 19.0 of Dailymaverick.co.za google news results.
# 190 results of site Dailymaverick.co.za scraped successfully!
# Scraping page 20.0 of Dailymaverick.co.za google news results.
# 200 results of site Dailymaverick.co.za scraped successfully!
# Scraping page 21.0 of Dailymaverick.co.za google news results.
# 210 results of site Dailymaverick.co.za scraped successfully!
# Scraping page 22.0 of Dailymaverick.co.za google news results.
# 220 results of site Dailymaverick.co.za scraped successfully!
# Scraping page 23.0 of Dailymaverick.co.za google news results.
# 230 results of site Dailymaverick.co.za scraped successfully!
# Scraping page 24.0 of Dailymaverick.co.za google news results.
# 240 results of site Dailymaverick.co.za scraped successfully!
# Scraping page 25.0 of Dailymaverick.co.za google news results.
# 250 results of site Dailymaverick.co.za scraped successfully!
# Scraping page 26.0 of Dailymaverick.co.za google news results.
# 260 results of site Dailymaverick.co.za scraped successfully!
# Scraping page 27.0 of Dailymaverick.co.za google news results.
# 270 results of site Dailymaverick.co.za scraped successfully!
# Scraping page 28.0 of Dailymaverick.co.za google news results.
# 280 results of site Dailymaverick.co.za scraped successfully!
# Scraping page 29.0 of Dailymaverick.co.za google news results.
# 290 results of site Dailymaverick.co.za scraped successfully!
# Scraping page 30.0 of Dailymaverick.co.za google news results.
# 300 results of site Dailymaverick.co.za scraped successfully!
# Scraping page 31.0 of Dailymaverick.co.za google news results.
# 310 results of site Dailymaverick.co.za scraped successfully!
# Saved data from 310 articles of Dailymaverick.co.za to .csv!
# Scraping page 1.0 of Vodacom.co.za google news results.
# 10 results of site Vodacom.co.za scraped successfully!
# Scraping page 2.0 of Vodacom.co.za google news results.
# 20 results of site Vodacom.co.za scraped successfully!
# Scraping page 3.0 of Vodacom.co.za google news results.
# 30 results of site Vodacom.co.za scraped successfully!
# Scraping page 4.0 of Vodacom.co.za google news results.
# 40 results of site Vodacom.co.za scraped successfully!
# Scraping page 5.0 of Vodacom.co.za google news results.
# 50 results of site Vodacom.co.za scraped successfully!
# Scraping page 6.0 of Vodacom.co.za google news results.
# 60 results of site Vodacom.co.za scraped successfully!
# Scraping page 7.0 of Vodacom.co.za google news results.
# 70 results of site Vodacom.co.za scraped successfully!
# Scraping page 8.0 of Vodacom.co.za google news results.
# 80 results of site Vodacom.co.za scraped successfully!
# Scraping page 9.0 of Vodacom.co.za google news results.
# 90 results of site Vodacom.co.za scraped successfully!
# Scraping page 10.0 of Vodacom.co.za google news results.
# 100 results of site Vodacom.co.za scraped successfully!
# Scraping page 11.0 of Vodacom.co.za google news results.
# 110 results of site Vodacom.co.za scraped successfully!
# Scraping page 12.0 of Vodacom.co.za google news results.
# 120 results of site Vodacom.co.za scraped successfully!
# Scraping page 13.0 of Vodacom.co.za google news results.
# 130 results of site Vodacom.co.za scraped successfully!
# Scraping page 14.0 of Vodacom.co.za google news results.
# 140 results of site Vodacom.co.za scraped successfully!
# Scraping page 15.0 of Vodacom.co.za google news results.
# 150 results of site Vodacom.co.za scraped successfully!
# Scraping page 16.0 of Vodacom.co.za google news results.
# 160 results of site Vodacom.co.za scraped successfully!
# Scraping page 17.0 of Vodacom.co.za google news results.
# 170 results of site Vodacom.co.za scraped successfully!
# Scraping page 18.0 of Vodacom.co.za google news results.
# 180 results of site Vodacom.co.za scraped successfully!
# Scraping page 19.0 of Vodacom.co.za google news results.
# 190 results of site Vodacom.co.za scraped successfully!
# Scraping page 20.0 of Vodacom.co.za google news results.
# 200 results of site Vodacom.co.za scraped successfully!
# Scraping page 21.0 of Vodacom.co.za google news results.
# 210 results of site Vodacom.co.za scraped successfully!
# Scraping page 22.0 of Vodacom.co.za google news results.
# 220 results of site Vodacom.co.za scraped successfully!
# Scraping page 23.0 of Vodacom.co.za google news results.
# 230 results of site Vodacom.co.za scraped successfully!
# Scraping page 24.0 of Vodacom.co.za google news results.
# 240 results of site Vodacom.co.za scraped successfully!
# Scraping page 25.0 of Vodacom.co.za google news results.
# 250 results of site Vodacom.co.za scraped successfully!
# Scraping page 26.0 of Vodacom.co.za google news results.
# 260 results of site Vodacom.co.za scraped successfully!
# Scraping page 27.0 of Vodacom.co.za google news results.
# 270 results of site Vodacom.co.za scraped successfully!
# Scraping page 28.0 of Vodacom.co.za google news results.
# 280 results of site Vodacom.co.za scraped successfully!
# Scraping page 29.0 of Vodacom.co.za google news results.
# 290 results of site Vodacom.co.za scraped successfully!
# Scraping page 30.0 of Vodacom.co.za google news results.
# 300 results of site Vodacom.co.za scraped successfully!
# Scraping page 31.0 of Vodacom.co.za google news results.
# Saved data from 295 articles of Vodacom.co.za to .csv!
# Scraping page 1.0 of Sowetanlive.co.za google news results.
# 10 results of site Sowetanlive.co.za scraped successfully!
# Scraping page 2.0 of Sowetanlive.co.za google news results.
# 20 results of site Sowetanlive.co.za scraped successfully!
# Scraping page 3.0 of Sowetanlive.co.za google news results.
# 30 results of site Sowetanlive.co.za scraped successfully!
# Scraping page 4.0 of Sowetanlive.co.za google news results.
# 40 results of site Sowetanlive.co.za scraped successfully!
# Scraping page 5.0 of Sowetanlive.co.za google news results.
# 50 results of site Sowetanlive.co.za scraped successfully!
# Scraping page 6.0 of Sowetanlive.co.za google news results.
# 60 results of site Sowetanlive.co.za scraped successfully!
# Scraping page 7.0 of Sowetanlive.co.za google news results.
# 70 results of site Sowetanlive.co.za scraped successfully!
# Scraping page 8.0 of Sowetanlive.co.za google news results.
# 80 results of site Sowetanlive.co.za scraped successfully!
# Scraping page 9.0 of Sowetanlive.co.za google news results.
# 90 results of site Sowetanlive.co.za scraped successfully!
# Scraping page 10.0 of Sowetanlive.co.za google news results.
# 100 results of site Sowetanlive.co.za scraped successfully!
# Scraping page 11.0 of Sowetanlive.co.za google news results.
# 110 results of site Sowetanlive.co.za scraped successfully!
# Scraping page 12.0 of Sowetanlive.co.za google news results.
# 120 results of site Sowetanlive.co.za scraped successfully!
# Scraping page 13.0 of Sowetanlive.co.za google news results.
# 130 results of site Sowetanlive.co.za scraped successfully!
# Scraping page 14.0 of Sowetanlive.co.za google news results.
# 140 results of site Sowetanlive.co.za scraped successfully!
# Scraping page 15.0 of Sowetanlive.co.za google news results.
# 150 results of site Sowetanlive.co.za scraped successfully!
# Scraping page 16.0 of Sowetanlive.co.za google news results.
# 160 results of site Sowetanlive.co.za scraped successfully!
# Scraping page 17.0 of Sowetanlive.co.za google news results.
# 170 results of site Sowetanlive.co.za scraped successfully!
# Scraping page 18.0 of Sowetanlive.co.za google news results.
# 180 results of site Sowetanlive.co.za scraped successfully!
# Scraping page 19.0 of Sowetanlive.co.za google news results.
# 190 results of site Sowetanlive.co.za scraped successfully!
# Scraping page 20.0 of Sowetanlive.co.za google news results.
# 200 results of site Sowetanlive.co.za scraped successfully!
# Scraping page 21.0 of Sowetanlive.co.za google news results.
# 210 results of site Sowetanlive.co.za scraped successfully!
# Scraping page 22.0 of Sowetanlive.co.za google news results.
# 220 results of site Sowetanlive.co.za scraped successfully!
# Scraping page 23.0 of Sowetanlive.co.za google news results.
# 230 results of site Sowetanlive.co.za scraped successfully!
# Scraping page 24.0 of Sowetanlive.co.za google news results.
# 240 results of site Sowetanlive.co.za scraped successfully!
# Scraping page 25.0 of Sowetanlive.co.za google news results.
# 250 results of site Sowetanlive.co.za scraped successfully!
# Scraping page 26.0 of Sowetanlive.co.za google news results.
# 260 results of site Sowetanlive.co.za scraped successfully!
# Scraping page 27.0 of Sowetanlive.co.za google news results.
# 270 results of site Sowetanlive.co.za scraped successfully!
# Scraping page 28.0 of Sowetanlive.co.za google news results.
# 280 results of site Sowetanlive.co.za scraped successfully!
# Scraping page 29.0 of Sowetanlive.co.za google news results.
# 290 results of site Sowetanlive.co.za scraped successfully!
# Scraping page 30.0 of Sowetanlive.co.za google news results.
# 300 results of site Sowetanlive.co.za scraped successfully!
# Scraping page 31.0 of Sowetanlive.co.za google news results.
# 310 results of site Sowetanlive.co.za scraped successfully!
# Saved data from 310 articles of Sowetanlive.co.za to .csv!
# Scraping page 1.0 of mg.co.za google news results.
# 10 results of site mg.co.za scraped successfully!
# Scraping page 2.0 of mg.co.za google news results.
# 20 results of site mg.co.za scraped successfully!
# Scraping page 3.0 of mg.co.za google news results.
# 30 results of site mg.co.za scraped successfully!
# Scraping page 4.0 of mg.co.za google news results.
# 40 results of site mg.co.za scraped successfully!
# Scraping page 5.0 of mg.co.za google news results.
# 50 results of site mg.co.za scraped successfully!
# Scraping page 6.0 of mg.co.za google news results.
# 60 results of site mg.co.za scraped successfully!
# Scraping page 7.0 of mg.co.za google news results.
# 70 results of site mg.co.za scraped successfully!
# Scraping page 8.0 of mg.co.za google news results.
# 80 results of site mg.co.za scraped successfully!
# Scraping page 9.0 of mg.co.za google news results.
# 90 results of site mg.co.za scraped successfully!
# Scraping page 10.0 of mg.co.za google news results.
# 100 results of site mg.co.za scraped successfully!
# Scraping page 11.0 of mg.co.za google news results.
# 110 results of site mg.co.za scraped successfully!
# Scraping page 12.0 of mg.co.za google news results.
# 120 results of site mg.co.za scraped successfully!
# Scraping page 13.0 of mg.co.za google news results.
# 130 results of site mg.co.za scraped successfully!
# Scraping page 14.0 of mg.co.za google news results.
# 140 results of site mg.co.za scraped successfully!
# Scraping page 15.0 of mg.co.za google news results.
# 150 results of site mg.co.za scraped successfully!
# Scraping page 16.0 of mg.co.za google news results.
# 160 results of site mg.co.za scraped successfully!
# Scraping page 17.0 of mg.co.za google news results.
# 170 results of site mg.co.za scraped successfully!
# Scraping page 18.0 of mg.co.za google news results.
# 180 results of site mg.co.za scraped successfully!
# Scraping page 19.0 of mg.co.za google news results.
# 190 results of site mg.co.za scraped successfully!
# Scraping page 20.0 of mg.co.za google news results.
# 200 results of site mg.co.za scraped successfully!
# Scraping page 21.0 of mg.co.za google news results.
# 210 results of site mg.co.za scraped successfully!
# Scraping page 22.0 of mg.co.za google news results.
# 220 results of site mg.co.za scraped successfully!
# Scraping page 23.0 of mg.co.za google news results.
# 230 results of site mg.co.za scraped successfully!
# Scraping page 24.0 of mg.co.za google news results.
# 240 results of site mg.co.za scraped successfully!
# Scraping page 25.0 of mg.co.za google news results.
# 250 results of site mg.co.za scraped successfully!
# Scraping page 26.0 of mg.co.za google news results.
# 260 results of site mg.co.za scraped successfully!
# Scraping page 27.0 of mg.co.za google news results.
# 270 results of site mg.co.za scraped successfully!
# Scraping page 28.0 of mg.co.za google news results.
# 280 results of site mg.co.za scraped successfully!
# Scraping page 29.0 of mg.co.za google news results.
# 290 results of site mg.co.za scraped successfully!
# Scraping page 30.0 of mg.co.za google news results.
# 300 results of site mg.co.za scraped successfully!
# Scraping page 31.0 of mg.co.za google news results.
# 310 results of site mg.co.za scraped successfully!
# Saved data from 310 articles of mg.co.za to .csv!
# Scraping page 1.0 of MyBroadband.co.za google news results.
# 10 results of site MyBroadband.co.za scraped successfully!
# Scraping page 2.0 of MyBroadband.co.za google news results.
# 20 results of site MyBroadband.co.za scraped successfully!
# Scraping page 3.0 of MyBroadband.co.za google news results.
# 30 results of site MyBroadband.co.za scraped successfully!
# Scraping page 4.0 of MyBroadband.co.za google news results.
# 40 results of site MyBroadband.co.za scraped successfully!
# Scraping page 5.0 of MyBroadband.co.za google news results.
# 50 results of site MyBroadband.co.za scraped successfully!
# Scraping page 6.0 of MyBroadband.co.za google news results.
# 60 results of site MyBroadband.co.za scraped successfully!
# Scraping page 7.0 of MyBroadband.co.za google news results.
# 70 results of site MyBroadband.co.za scraped successfully!
# Scraping page 8.0 of MyBroadband.co.za google news results.
# 80 results of site MyBroadband.co.za scraped successfully!
# Scraping page 9.0 of MyBroadband.co.za google news results.
# 90 results of site MyBroadband.co.za scraped successfully!
# Scraping page 10.0 of MyBroadband.co.za google news results.
# 100 results of site MyBroadband.co.za scraped successfully!
# Scraping page 11.0 of MyBroadband.co.za google news results.
# 110 results of site MyBroadband.co.za scraped successfully!
# Scraping page 12.0 of MyBroadband.co.za google news results.
# 120 results of site MyBroadband.co.za scraped successfully!
# Scraping page 13.0 of MyBroadband.co.za google news results.
# 130 results of site MyBroadband.co.za scraped successfully!
# Scraping page 14.0 of MyBroadband.co.za google news results.
# 140 results of site MyBroadband.co.za scraped successfully!
# Scraping page 15.0 of MyBroadband.co.za google news results.
# 150 results of site MyBroadband.co.za scraped successfully!
# Scraping page 16.0 of MyBroadband.co.za google news results.
# 160 results of site MyBroadband.co.za scraped successfully!
# Scraping page 17.0 of MyBroadband.co.za google news results.
# 170 results of site MyBroadband.co.za scraped successfully!
# Scraping page 18.0 of MyBroadband.co.za google news results.
# 180 results of site MyBroadband.co.za scraped successfully!
# Scraping page 19.0 of MyBroadband.co.za google news results.
# 190 results of site MyBroadband.co.za scraped successfully!
# Scraping page 20.0 of MyBroadband.co.za google news results.
# 200 results of site MyBroadband.co.za scraped successfully!
# Scraping page 21.0 of MyBroadband.co.za google news results.
# 210 results of site MyBroadband.co.za scraped successfully!
# Scraping page 22.0 of MyBroadband.co.za google news results.
# 220 results of site MyBroadband.co.za scraped successfully!
# Scraping page 23.0 of MyBroadband.co.za google news results.
# 230 results of site MyBroadband.co.za scraped successfully!
# Scraping page 24.0 of MyBroadband.co.za google news results.
# 240 results of site MyBroadband.co.za scraped successfully!
# Scraping page 25.0 of MyBroadband.co.za google news results.
# 250 results of site MyBroadband.co.za scraped successfully!
# Scraping page 26.0 of MyBroadband.co.za google news results.
# 260 results of site MyBroadband.co.za scraped successfully!
# Scraping page 27.0 of MyBroadband.co.za google news results.
# 270 results of site MyBroadband.co.za scraped successfully!
# Scraping page 28.0 of MyBroadband.co.za google news results.
# 280 results of site MyBroadband.co.za scraped successfully!
# Scraping page 29.0 of MyBroadband.co.za google news results.
# 290 results of site MyBroadband.co.za scraped successfully!
# Scraping page 30.0 of MyBroadband.co.za google news results.
# 300 results of site MyBroadband.co.za scraped successfully!
# Scraping page 31.0 of MyBroadband.co.za google news results.
# 310 results of site MyBroadband.co.za scraped successfully!
# Saved data from 303 articles of MyBroadband.co.za to .csv!
# Scraping page 1.0 of Moneyweb.co.za google news results.
# 10 results of site Moneyweb.co.za scraped successfully!
# Scraping page 2.0 of Moneyweb.co.za google news results.
# 20 results of site Moneyweb.co.za scraped successfully!
# Scraping page 3.0 of Moneyweb.co.za google news results.
# 30 results of site Moneyweb.co.za scraped successfully!
# Scraping page 4.0 of Moneyweb.co.za google news results.
# 40 results of site Moneyweb.co.za scraped successfully!
# Scraping page 5.0 of Moneyweb.co.za google news results.
# 50 results of site Moneyweb.co.za scraped successfully!
# Scraping page 6.0 of Moneyweb.co.za google news results.
# 60 results of site Moneyweb.co.za scraped successfully!
# Scraping page 7.0 of Moneyweb.co.za google news results.
# 70 results of site Moneyweb.co.za scraped successfully!
# Scraping page 8.0 of Moneyweb.co.za google news results.
# 80 results of site Moneyweb.co.za scraped successfully!
# Scraping page 9.0 of Moneyweb.co.za google news results.
# 90 results of site Moneyweb.co.za scraped successfully!
# Scraping page 10.0 of Moneyweb.co.za google news results.
# 100 results of site Moneyweb.co.za scraped successfully!
# Scraping page 11.0 of Moneyweb.co.za google news results.
# 110 results of site Moneyweb.co.za scraped successfully!
# Scraping page 12.0 of Moneyweb.co.za google news results.
# 120 results of site Moneyweb.co.za scraped successfully!
# Scraping page 13.0 of Moneyweb.co.za google news results.
# 130 results of site Moneyweb.co.za scraped successfully!
# Scraping page 14.0 of Moneyweb.co.za google news results.
# 140 results of site Moneyweb.co.za scraped successfully!
# Scraping page 15.0 of Moneyweb.co.za google news results.
# 150 results of site Moneyweb.co.za scraped successfully!
# Scraping page 16.0 of Moneyweb.co.za google news results.
# 160 results of site Moneyweb.co.za scraped successfully!
# Scraping page 17.0 of Moneyweb.co.za google news results.
# 170 results of site Moneyweb.co.za scraped successfully!
# Scraping page 18.0 of Moneyweb.co.za google news results.
# 180 results of site Moneyweb.co.za scraped successfully!
# Scraping page 19.0 of Moneyweb.co.za google news results.
# 190 results of site Moneyweb.co.za scraped successfully!
# Scraping page 20.0 of Moneyweb.co.za google news results.
# 200 results of site Moneyweb.co.za scraped successfully!
# Scraping page 21.0 of Moneyweb.co.za google news results.
# 210 results of site Moneyweb.co.za scraped successfully!
# Scraping page 22.0 of Moneyweb.co.za google news results.
# 220 results of site Moneyweb.co.za scraped successfully!
# Scraping page 23.0 of Moneyweb.co.za google news results.
# 230 results of site Moneyweb.co.za scraped successfully!
# Scraping page 24.0 of Moneyweb.co.za google news results.
# 240 results of site Moneyweb.co.za scraped successfully!
# Scraping page 25.0 of Moneyweb.co.za google news results.
# 250 results of site Moneyweb.co.za scraped successfully!
# Scraping page 26.0 of Moneyweb.co.za google news results.
# 260 results of site Moneyweb.co.za scraped successfully!
# Scraping page 27.0 of Moneyweb.co.za google news results.
# 270 results of site Moneyweb.co.za scraped successfully!
# Scraping page 28.0 of Moneyweb.co.za google news results.
# Saved data from 268 articles of Moneyweb.co.za to .csv!
# Scraping page 1.0 of Businesslive.co.za google news results.
# 10 results of site Businesslive.co.za scraped successfully!
# Scraping page 2.0 of Businesslive.co.za google news results.
# 20 results of site Businesslive.co.za scraped successfully!
# Scraping page 3.0 of Businesslive.co.za google news results.
# 30 results of site Businesslive.co.za scraped successfully!
# Scraping page 4.0 of Businesslive.co.za google news results.
# 40 results of site Businesslive.co.za scraped successfully!
# Scraping page 5.0 of Businesslive.co.za google news results.
# 50 results of site Businesslive.co.za scraped successfully!
# Scraping page 6.0 of Businesslive.co.za google news results.
# 60 results of site Businesslive.co.za scraped successfully!
# Scraping page 7.0 of Businesslive.co.za google news results.
# 70 results of site Businesslive.co.za scraped successfully!
# Scraping page 8.0 of Businesslive.co.za google news results.
# 80 results of site Businesslive.co.za scraped successfully!
# Scraping page 9.0 of Businesslive.co.za google news results.
# 90 results of site Businesslive.co.za scraped successfully!
# Scraping page 10.0 of Businesslive.co.za google news results.
# 100 results of site Businesslive.co.za scraped successfully!
# Scraping page 11.0 of Businesslive.co.za google news results.
# 110 results of site Businesslive.co.za scraped successfully!
# Scraping page 12.0 of Businesslive.co.za google news results.
# 120 results of site Businesslive.co.za scraped successfully!
# Scraping page 13.0 of Businesslive.co.za google news results.
# 130 results of site Businesslive.co.za scraped successfully!
# Scraping page 14.0 of Businesslive.co.za google news results.
# 140 results of site Businesslive.co.za scraped successfully!
# Scraping page 15.0 of Businesslive.co.za google news results.
# 150 results of site Businesslive.co.za scraped successfully!
# Scraping page 16.0 of Businesslive.co.za google news results.
# 160 results of site Businesslive.co.za scraped successfully!
# Scraping page 17.0 of Businesslive.co.za google news results.
# 170 results of site Businesslive.co.za scraped successfully!
# Scraping page 18.0 of Businesslive.co.za google news results.
# 180 results of site Businesslive.co.za scraped successfully!
# Scraping page 19.0 of Businesslive.co.za google news results.
# 190 results of site Businesslive.co.za scraped successfully!
# Scraping page 20.0 of Businesslive.co.za google news results.
# 200 results of site Businesslive.co.za scraped successfully!
# Scraping page 21.0 of Businesslive.co.za google news results.
# 210 results of site Businesslive.co.za scraped successfully!
# Scraping page 22.0 of Businesslive.co.za google news results.
# 220 results of site Businesslive.co.za scraped successfully!
# Scraping page 23.0 of Businesslive.co.za google news results.
# 230 results of site Businesslive.co.za scraped successfully!
# Scraping page 24.0 of Businesslive.co.za google news results.
# 240 results of site Businesslive.co.za scraped successfully!
# Scraping page 25.0 of Businesslive.co.za google news results.
# 250 results of site Businesslive.co.za scraped successfully!
# Scraping page 26.0 of Businesslive.co.za google news results.
# 260 results of site Businesslive.co.za scraped successfully!
# Scraping page 27.0 of Businesslive.co.za google news results.
# 270 results of site Businesslive.co.za scraped successfully!
# Scraping page 28.0 of Businesslive.co.za google news results.
# 280 results of site Businesslive.co.za scraped successfully!
# Scraping page 29.0 of Businesslive.co.za google news results.
# 290 results of site Businesslive.co.za scraped successfully!
# Scraping page 30.0 of Businesslive.co.za google news results.
# 300 results of site Businesslive.co.za scraped successfully!
# Scraping page 31.0 of Businesslive.co.za google news results.
# 310 results of site Businesslive.co.za scraped successfully!
# Saved data from 310 articles of Businesslive.co.za to .csv!
# Scraping page 1.0 of Enca.com google news results.
# 10 results of site Enca.com scraped successfully!
# Scraping page 2.0 of Enca.com google news results.
# 20 results of site Enca.com scraped successfully!
# Scraping page 3.0 of Enca.com google news results.
# 30 results of site Enca.com scraped successfully!
# Scraping page 4.0 of Enca.com google news results.
# 40 results of site Enca.com scraped successfully!
# Scraping page 5.0 of Enca.com google news results.
# 50 results of site Enca.com scraped successfully!
# Scraping page 6.0 of Enca.com google news results.
# 60 results of site Enca.com scraped successfully!
# Scraping page 7.0 of Enca.com google news results.
# 70 results of site Enca.com scraped successfully!
# Scraping page 8.0 of Enca.com google news results.
# 80 results of site Enca.com scraped successfully!
# Scraping page 9.0 of Enca.com google news results.
# 90 results of site Enca.com scraped successfully!
# Scraping page 10.0 of Enca.com google news results.
# 100 results of site Enca.com scraped successfully!
# Scraping page 11.0 of Enca.com google news results.
# 110 results of site Enca.com scraped successfully!
# Scraping page 12.0 of Enca.com google news results.
# 120 results of site Enca.com scraped successfully!
# Scraping page 13.0 of Enca.com google news results.
# 130 results of site Enca.com scraped successfully!
# Scraping page 14.0 of Enca.com google news results.
# 140 results of site Enca.com scraped successfully!
# Scraping page 15.0 of Enca.com google news results.
# 150 results of site Enca.com scraped successfully!
# Scraping page 16.0 of Enca.com google news results.
# 160 results of site Enca.com scraped successfully!
# Scraping page 17.0 of Enca.com google news results.
# 170 results of site Enca.com scraped successfully!
# Scraping page 18.0 of Enca.com google news results.
# 180 results of site Enca.com scraped successfully!
# Scraping page 19.0 of Enca.com google news results.
# 190 results of site Enca.com scraped successfully!
# Scraping page 20.0 of Enca.com google news results.
# 200 results of site Enca.com scraped successfully!
# Scraping page 21.0 of Enca.com google news results.
# 210 results of site Enca.com scraped successfully!
# Scraping page 22.0 of Enca.com google news results.
# 220 results of site Enca.com scraped successfully!
# Scraping page 23.0 of Enca.com google news results.
# 230 results of site Enca.com scraped successfully!
# Scraping page 24.0 of Enca.com google news results.
# 240 results of site Enca.com scraped successfully!
# Scraping page 25.0 of Enca.com google news results.
# 250 results of site Enca.com scraped successfully!
# Scraping page 26.0 of Enca.com google news results.
# 260 results of site Enca.com scraped successfully!
# Scraping page 27.0 of Enca.com google news results.
# 270 results of site Enca.com scraped successfully!
# Scraping page 28.0 of Enca.com google news results.
# 280 results of site Enca.com scraped successfully!
# Scraping page 29.0 of Enca.com google news results.
# 290 results of site Enca.com scraped successfully!
# Scraping page 30.0 of Enca.com google news results.
# 300 results of site Enca.com scraped successfully!
# Scraping page 31.0 of Enca.com google news results.
# 310 results of site Enca.com scraped successfully!
# Saved data from 310 articles of Enca.com to .csv!
# Scraping page 1.0 of Capetownetc.com google news results.
# 10 results of site Capetownetc.com scraped successfully!
# Scraping page 2.0 of Capetownetc.com google news results.
# 20 results of site Capetownetc.com scraped successfully!
# Scraping page 3.0 of Capetownetc.com google news results.
# 30 results of site Capetownetc.com scraped successfully!
# Scraping page 4.0 of Capetownetc.com google news results.
# 40 results of site Capetownetc.com scraped successfully!
# Scraping page 5.0 of Capetownetc.com google news results.
# 50 results of site Capetownetc.com scraped successfully!
# Scraping page 6.0 of Capetownetc.com google news results.
# 60 results of site Capetownetc.com scraped successfully!
# Scraping page 7.0 of Capetownetc.com google news results.
# 70 results of site Capetownetc.com scraped successfully!
# Scraping page 8.0 of Capetownetc.com google news results.
# 80 results of site Capetownetc.com scraped successfully!
# Scraping page 9.0 of Capetownetc.com google news results.
# 90 results of site Capetownetc.com scraped successfully!
# Scraping page 10.0 of Capetownetc.com google news results.
# 100 results of site Capetownetc.com scraped successfully!
# Scraping page 11.0 of Capetownetc.com google news results.
# 110 results of site Capetownetc.com scraped successfully!
# Scraping page 12.0 of Capetownetc.com google news results.
# 120 results of site Capetownetc.com scraped successfully!
# Scraping page 13.0 of Capetownetc.com google news results.
# 130 results of site Capetownetc.com scraped successfully!
# Scraping page 14.0 of Capetownetc.com google news results.
# 140 results of site Capetownetc.com scraped successfully!
# Scraping page 15.0 of Capetownetc.com google news results.
# 150 results of site Capetownetc.com scraped successfully!
# Scraping page 16.0 of Capetownetc.com google news results.
# 160 results of site Capetownetc.com scraped successfully!
# Scraping page 17.0 of Capetownetc.com google news results.
# 170 results of site Capetownetc.com scraped successfully!
# Scraping page 18.0 of Capetownetc.com google news results.
# 180 results of site Capetownetc.com scraped successfully!
# Scraping page 19.0 of Capetownetc.com google news results.
# 190 results of site Capetownetc.com scraped successfully!
# Scraping page 20.0 of Capetownetc.com google news results.
# 200 results of site Capetownetc.com scraped successfully!
# Scraping page 21.0 of Capetownetc.com google news results.
# 210 results of site Capetownetc.com scraped successfully!
# Scraping page 22.0 of Capetownetc.com google news results.
# 220 results of site Capetownetc.com scraped successfully!
# Scraping page 23.0 of Capetownetc.com google news results.
# 230 results of site Capetownetc.com scraped successfully!
# Scraping page 24.0 of Capetownetc.com google news results.
# 240 results of site Capetownetc.com scraped successfully!
# Scraping page 25.0 of Capetownetc.com google news results.
# 250 results of site Capetownetc.com scraped successfully!
# Scraping page 26.0 of Capetownetc.com google news results.
# 260 results of site Capetownetc.com scraped successfully!
# Scraping page 27.0 of Capetownetc.com google news results.
# 270 results of site Capetownetc.com scraped successfully!
# Scraping page 28.0 of Capetownetc.com google news results.
# 280 results of site Capetownetc.com scraped successfully!
# Scraping page 29.0 of Capetownetc.com google news results.
# 290 results of site Capetownetc.com scraped successfully!
# Scraping page 30.0 of Capetownetc.com google news results.
# 300 results of site Capetownetc.com scraped successfully!
# Scraping page 31.0 of Capetownetc.com google news results.
# 310 results of site Capetownetc.com scraped successfully!
# Saved data from 310 articles of Capetownetc.com to .csv!
# Scraping page 1.0 of iol.co.za google news results.
# 10 results of site iol.co.za scraped successfully!
# Scraping page 2.0 of iol.co.za google news results.
# 20 results of site iol.co.za scraped successfully!
# Scraping page 3.0 of iol.co.za google news results.
# 30 results of site iol.co.za scraped successfully!
# Scraping page 4.0 of iol.co.za google news results.
# 40 results of site iol.co.za scraped successfully!
# Scraping page 5.0 of iol.co.za google news results.
# 50 results of site iol.co.za scraped successfully!
# Scraping page 6.0 of iol.co.za google news results.
# 60 results of site iol.co.za scraped successfully!
# Scraping page 7.0 of iol.co.za google news results.
# 70 results of site iol.co.za scraped successfully!
# Scraping page 8.0 of iol.co.za google news results.
# 80 results of site iol.co.za scraped successfully!
# Scraping page 9.0 of iol.co.za google news results.
# 90 results of site iol.co.za scraped successfully!
# Scraping page 10.0 of iol.co.za google news results.
# 100 results of site iol.co.za scraped successfully!
# Scraping page 11.0 of iol.co.za google news results.
# 110 results of site iol.co.za scraped successfully!
# Scraping page 12.0 of iol.co.za google news results.
# 120 results of site iol.co.za scraped successfully!
# Scraping page 13.0 of iol.co.za google news results.
# 130 results of site iol.co.za scraped successfully!
# Scraping page 14.0 of iol.co.za google news results.
# 140 results of site iol.co.za scraped successfully!
# Scraping page 15.0 of iol.co.za google news results.
# 150 results of site iol.co.za scraped successfully!
# Scraping page 16.0 of iol.co.za google news results.
# 160 results of site iol.co.za scraped successfully!
# Scraping page 17.0 of iol.co.za google news results.
# 170 results of site iol.co.za scraped successfully!
# Scraping page 18.0 of iol.co.za google news results.
# 180 results of site iol.co.za scraped successfully!
# Scraping page 19.0 of iol.co.za google news results.
# 190 results of site iol.co.za scraped successfully!
# Scraping page 20.0 of iol.co.za google news results.
# 200 results of site iol.co.za scraped successfully!
# Scraping page 21.0 of iol.co.za google news results.
# 210 results of site iol.co.za scraped successfully!
# Scraping page 22.0 of iol.co.za google news results.
# 220 results of site iol.co.za scraped successfully!
# Scraping page 23.0 of iol.co.za google news results.
# 230 results of site iol.co.za scraped successfully!
# Scraping page 24.0 of iol.co.za google news results.
# 240 results of site iol.co.za scraped successfully!
# Scraping page 25.0 of iol.co.za google news results.
# 250 results of site iol.co.za scraped successfully!
# Scraping page 26.0 of iol.co.za google news results.
# 260 results of site iol.co.za scraped successfully!
# Scraping page 27.0 of iol.co.za google news results.
# 270 results of site iol.co.za scraped successfully!
# Scraping page 28.0 of iol.co.za google news results.
# 280 results of site iol.co.za scraped successfully!
# Scraping page 29.0 of iol.co.za google news results.
# 290 results of site iol.co.za scraped successfully!
# Scraping page 30.0 of iol.co.za google news results.
# 300 results of site iol.co.za scraped successfully!
# Scraping page 31.0 of iol.co.za google news results.
# 310 results of site iol.co.za scraped successfully!
# Saved data from 310 articles of iol.co.za to .csv!
# Scraping page 1.0 of heraldlive.co.za google news results.
# 10 results of site heraldlive.co.za scraped successfully!
# Scraping page 2.0 of heraldlive.co.za google news results.
# 20 results of site heraldlive.co.za scraped successfully!
# Scraping page 3.0 of heraldlive.co.za google news results.
# 30 results of site heraldlive.co.za scraped successfully!
# Scraping page 4.0 of heraldlive.co.za google news results.
# 40 results of site heraldlive.co.za scraped successfully!
# Scraping page 5.0 of heraldlive.co.za google news results.
# 50 results of site heraldlive.co.za scraped successfully!
# Scraping page 6.0 of heraldlive.co.za google news results.
# 60 results of site heraldlive.co.za scraped successfully!
# Scraping page 7.0 of heraldlive.co.za google news results.
# 70 results of site heraldlive.co.za scraped successfully!
# Scraping page 8.0 of heraldlive.co.za google news results.
# 80 results of site heraldlive.co.za scraped successfully!
# Scraping page 9.0 of heraldlive.co.za google news results.
# 90 results of site heraldlive.co.za scraped successfully!
# Scraping page 10.0 of heraldlive.co.za google news results.
# 100 results of site heraldlive.co.za scraped successfully!
# Scraping page 11.0 of heraldlive.co.za google news results.
# 110 results of site heraldlive.co.za scraped successfully!
# Scraping page 12.0 of heraldlive.co.za google news results.
# 120 results of site heraldlive.co.za scraped successfully!
# Scraping page 13.0 of heraldlive.co.za google news results.
# 130 results of site heraldlive.co.za scraped successfully!
# Scraping page 14.0 of heraldlive.co.za google news results.
# 140 results of site heraldlive.co.za scraped successfully!
# Scraping page 15.0 of heraldlive.co.za google news results.
# 150 results of site heraldlive.co.za scraped successfully!
# Scraping page 16.0 of heraldlive.co.za google news results.
# 160 results of site heraldlive.co.za scraped successfully!
# Scraping page 17.0 of heraldlive.co.za google news results.
# 170 results of site heraldlive.co.za scraped successfully!
# Scraping page 18.0 of heraldlive.co.za google news results.
# 180 results of site heraldlive.co.za scraped successfully!
# Scraping page 19.0 of heraldlive.co.za google news results.
# 190 results of site heraldlive.co.za scraped successfully!
# Scraping page 20.0 of heraldlive.co.za google news results.
# 200 results of site heraldlive.co.za scraped successfully!
# Scraping page 21.0 of heraldlive.co.za google news results.
# 210 results of site heraldlive.co.za scraped successfully!
# Scraping page 22.0 of heraldlive.co.za google news results.
# 220 results of site heraldlive.co.za scraped successfully!
# Scraping page 23.0 of heraldlive.co.za google news results.
# 230 results of site heraldlive.co.za scraped successfully!
# Scraping page 24.0 of heraldlive.co.za google news results.
# 240 results of site heraldlive.co.za scraped successfully!
# Scraping page 25.0 of heraldlive.co.za google news results.
# 250 results of site heraldlive.co.za scraped successfully!
# Scraping page 26.0 of heraldlive.co.za google news results.
# 260 results of site heraldlive.co.za scraped successfully!
# Scraping page 27.0 of heraldlive.co.za google news results.
# 270 results of site heraldlive.co.za scraped successfully!
# Scraping page 28.0 of heraldlive.co.za google news results.
# 280 results of site heraldlive.co.za scraped successfully!
# Scraping page 29.0 of heraldlive.co.za google news results.
# 290 results of site heraldlive.co.za scraped successfully!
# Scraping page 30.0 of heraldlive.co.za google news results.
# 300 results of site heraldlive.co.za scraped successfully!
# Scraping page 31.0 of heraldlive.co.za google news results.
# 310 results of site heraldlive.co.za scraped successfully!
# Saved data from 307 articles of heraldlive.co.za to .csv!
# Scraping page 1.0 of dispatchlive.co.za google news results.
# 10 results of site dispatchlive.co.za scraped successfully!
# Scraping page 2.0 of dispatchlive.co.za google news results.
# 20 results of site dispatchlive.co.za scraped successfully!
# Scraping page 3.0 of dispatchlive.co.za google news results.
# 30 results of site dispatchlive.co.za scraped successfully!
# Scraping page 4.0 of dispatchlive.co.za google news results.
# 40 results of site dispatchlive.co.za scraped successfully!
# Scraping page 5.0 of dispatchlive.co.za google news results.
# 50 results of site dispatchlive.co.za scraped successfully!
# Scraping page 6.0 of dispatchlive.co.za google news results.
# 60 results of site dispatchlive.co.za scraped successfully!
# Scraping page 7.0 of dispatchlive.co.za google news results.
# 70 results of site dispatchlive.co.za scraped successfully!
# Scraping page 8.0 of dispatchlive.co.za google news results.
# 80 results of site dispatchlive.co.za scraped successfully!
# Scraping page 9.0 of dispatchlive.co.za google news results.
# 90 results of site dispatchlive.co.za scraped successfully!
# Scraping page 10.0 of dispatchlive.co.za google news results.
# 100 results of site dispatchlive.co.za scraped successfully!
# Scraping page 11.0 of dispatchlive.co.za google news results.
# 110 results of site dispatchlive.co.za scraped successfully!
# Scraping page 12.0 of dispatchlive.co.za google news results.
# 120 results of site dispatchlive.co.za scraped successfully!
# Scraping page 13.0 of dispatchlive.co.za google news results.
# 130 results of site dispatchlive.co.za scraped successfully!
# Scraping page 14.0 of dispatchlive.co.za google news results.
# 140 results of site dispatchlive.co.za scraped successfully!
# Scraping page 15.0 of dispatchlive.co.za google news results.
# 150 results of site dispatchlive.co.za scraped successfully!
# Scraping page 16.0 of dispatchlive.co.za google news results.
# 160 results of site dispatchlive.co.za scraped successfully!
# Scraping page 17.0 of dispatchlive.co.za google news results.
# 170 results of site dispatchlive.co.za scraped successfully!
# Scraping page 18.0 of dispatchlive.co.za google news results.
# 180 results of site dispatchlive.co.za scraped successfully!
# Scraping page 19.0 of dispatchlive.co.za google news results.
# 190 results of site dispatchlive.co.za scraped successfully!
# Scraping page 20.0 of dispatchlive.co.za google news results.
# 200 results of site dispatchlive.co.za scraped successfully!
# Scraping page 21.0 of dispatchlive.co.za google news results.
# 210 results of site dispatchlive.co.za scraped successfully!
# Scraping page 22.0 of dispatchlive.co.za google news results.
# 220 results of site dispatchlive.co.za scraped successfully!
# Scraping page 23.0 of dispatchlive.co.za google news results.
# 230 results of site dispatchlive.co.za scraped successfully!
# Scraping page 24.0 of dispatchlive.co.za google news results.
# 240 results of site dispatchlive.co.za scraped successfully!
# Scraping page 25.0 of dispatchlive.co.za google news results.
# 250 results of site dispatchlive.co.za scraped successfully!
# Scraping page 26.0 of dispatchlive.co.za google news results.
# 260 results of site dispatchlive.co.za scraped successfully!
# Scraping page 27.0 of dispatchlive.co.za google news results.
# 270 results of site dispatchlive.co.za scraped successfully!
# Scraping page 28.0 of dispatchlive.co.za google news results.
# 280 results of site dispatchlive.co.za scraped successfully!
# Scraping page 29.0 of dispatchlive.co.za google news results.
# 290 results of site dispatchlive.co.za scraped successfully!
# Scraping page 30.0 of dispatchlive.co.za google news results.
# 300 results of site dispatchlive.co.za scraped successfully!
# Scraping page 31.0 of dispatchlive.co.za google news results.
# 310 results of site dispatchlive.co.za scraped successfully!
# Saved data from 310 articles of dispatchlive.co.za to .csv!
# Scraping page 1.0 of dailysun.co.za google news results.
# 10 results of site dailysun.co.za scraped successfully!
# Scraping page 2.0 of dailysun.co.za google news results.
# 20 results of site dailysun.co.za scraped successfully!
# Scraping page 3.0 of dailysun.co.za google news results.
# 30 results of site dailysun.co.za scraped successfully!
# Scraping page 4.0 of dailysun.co.za google news results.
# 40 results of site dailysun.co.za scraped successfully!
# Scraping page 5.0 of dailysun.co.za google news results.
# 50 results of site dailysun.co.za scraped successfully!
# Scraping page 6.0 of dailysun.co.za google news results.
# 60 results of site dailysun.co.za scraped successfully!
# Scraping page 7.0 of dailysun.co.za google news results.
# 70 results of site dailysun.co.za scraped successfully!
# Scraping page 8.0 of dailysun.co.za google news results.
# 80 results of site dailysun.co.za scraped successfully!
# Scraping page 9.0 of dailysun.co.za google news results.
# 90 results of site dailysun.co.za scraped successfully!
# Scraping page 10.0 of dailysun.co.za google news results.
# 100 results of site dailysun.co.za scraped successfully!
# Scraping page 11.0 of dailysun.co.za google news results.
# 110 results of site dailysun.co.za scraped successfully!
# Scraping page 12.0 of dailysun.co.za google news results.
# 120 results of site dailysun.co.za scraped successfully!
# Scraping page 13.0 of dailysun.co.za google news results.
# 130 results of site dailysun.co.za scraped successfully!
# Scraping page 14.0 of dailysun.co.za google news results.
# 140 results of site dailysun.co.za scraped successfully!
# Scraping page 15.0 of dailysun.co.za google news results.
# 150 results of site dailysun.co.za scraped successfully!
# Scraping page 16.0 of dailysun.co.za google news results.
# 160 results of site dailysun.co.za scraped successfully!
# Scraping page 17.0 of dailysun.co.za google news results.
# 170 results of site dailysun.co.za scraped successfully!
# Scraping page 18.0 of dailysun.co.za google news results.
# 180 results of site dailysun.co.za scraped successfully!
# Scraping page 19.0 of dailysun.co.za google news results.
# 190 results of site dailysun.co.za scraped successfully!
# Scraping page 20.0 of dailysun.co.za google news results.
# 200 results of site dailysun.co.za scraped successfully!
# Scraping page 21.0 of dailysun.co.za google news results.
# 210 results of site dailysun.co.za scraped successfully!
# Scraping page 22.0 of dailysun.co.za google news results.
# 220 results of site dailysun.co.za scraped successfully!
# Scraping page 23.0 of dailysun.co.za google news results.
# 230 results of site dailysun.co.za scraped successfully!
# Scraping page 24.0 of dailysun.co.za google news results.
# 240 results of site dailysun.co.za scraped successfully!
# Scraping page 25.0 of dailysun.co.za google news results.
# 250 results of site dailysun.co.za scraped successfully!
# Scraping page 26.0 of dailysun.co.za google news results.
# 260 results of site dailysun.co.za scraped successfully!
# Scraping page 27.0 of dailysun.co.za google news results.
# 270 results of site dailysun.co.za scraped successfully!
# Scraping page 28.0 of dailysun.co.za google news results.
# 280 results of site dailysun.co.za scraped successfully!
# Scraping page 29.0 of dailysun.co.za google news results.
# 290 results of site dailysun.co.za scraped successfully!
# Scraping page 30.0 of dailysun.co.za google news results.
# 300 results of site dailysun.co.za scraped successfully!
# Scraping page 31.0 of dailysun.co.za google news results.
# Saved data from 299 articles of dailysun.co.za to .csv!
# Scraping page 1.0 of cbn.co.za google news results.
# 10 results of site cbn.co.za scraped successfully!
# Scraping page 2.0 of cbn.co.za google news results.
# 20 results of site cbn.co.za scraped successfully!
# Scraping page 3.0 of cbn.co.za google news results.
# 30 results of site cbn.co.za scraped successfully!
# Scraping page 4.0 of cbn.co.za google news results.
# 40 results of site cbn.co.za scraped successfully!
# Scraping page 5.0 of cbn.co.za google news results.
# 50 results of site cbn.co.za scraped successfully!
# Scraping page 6.0 of cbn.co.za google news results.
# 60 results of site cbn.co.za scraped successfully!
# Scraping page 7.0 of cbn.co.za google news results.
# 70 results of site cbn.co.za scraped successfully!
# Scraping page 8.0 of cbn.co.za google news results.
# 80 results of site cbn.co.za scraped successfully!
# Scraping page 9.0 of cbn.co.za google news results.
# 90 results of site cbn.co.za scraped successfully!
# Scraping page 10.0 of cbn.co.za google news results.
# 100 results of site cbn.co.za scraped successfully!
# Scraping page 11.0 of cbn.co.za google news results.
# 110 results of site cbn.co.za scraped successfully!
# Scraping page 12.0 of cbn.co.za google news results.
# 120 results of site cbn.co.za scraped successfully!
# Scraping page 13.0 of cbn.co.za google news results.
# 130 results of site cbn.co.za scraped successfully!
# Scraping page 14.0 of cbn.co.za google news results.
# 140 results of site cbn.co.za scraped successfully!
# Scraping page 15.0 of cbn.co.za google news results.
# 150 results of site cbn.co.za scraped successfully!
# Scraping page 16.0 of cbn.co.za google news results.
# 160 results of site cbn.co.za scraped successfully!
# Scraping page 17.0 of cbn.co.za google news results.
# 170 results of site cbn.co.za scraped successfully!
# Scraping page 18.0 of cbn.co.za google news results.
# 180 results of site cbn.co.za scraped successfully!
# Scraping page 19.0 of cbn.co.za google news results.
# 190 results of site cbn.co.za scraped successfully!
# Scraping page 20.0 of cbn.co.za google news results.
# 200 results of site cbn.co.za scraped successfully!
# Scraping page 21.0 of cbn.co.za google news results.
# 210 results of site cbn.co.za scraped successfully!
# Scraping page 22.0 of cbn.co.za google news results.
# 220 results of site cbn.co.za scraped successfully!
# Scraping page 23.0 of cbn.co.za google news results.
# 230 results of site cbn.co.za scraped successfully!
# Scraping page 24.0 of cbn.co.za google news results.
# 240 results of site cbn.co.za scraped successfully!
# Scraping page 25.0 of cbn.co.za google news results.
# 250 results of site cbn.co.za scraped successfully!
# Scraping page 26.0 of cbn.co.za google news results.
# 260 results of site cbn.co.za scraped successfully!
# Scraping page 27.0 of cbn.co.za google news results.
# 270 results of site cbn.co.za scraped successfully!
# Scraping page 28.0 of cbn.co.za google news results.
# 280 results of site cbn.co.za scraped successfully!
# Scraping page 29.0 of cbn.co.za google news results.
# 290 results of site cbn.co.za scraped successfully!
# Scraping page 30.0 of cbn.co.za google news results.
# 300 results of site cbn.co.za scraped successfully!
# Scraping page 31.0 of cbn.co.za google news results.
# Saved data from 298 articles of cbn.co.za to .csv!
# Scraping page 1.0 of lowvelder.co.za google news results.
# 10 results of site lowvelder.co.za scraped successfully!
# Scraping page 2.0 of lowvelder.co.za google news results.
# 20 results of site lowvelder.co.za scraped successfully!
# Scraping page 3.0 of lowvelder.co.za google news results.
# 30 results of site lowvelder.co.za scraped successfully!
# Scraping page 4.0 of lowvelder.co.za google news results.
# 40 results of site lowvelder.co.za scraped successfully!
# Scraping page 5.0 of lowvelder.co.za google news results.
# 50 results of site lowvelder.co.za scraped successfully!
# Scraping page 6.0 of lowvelder.co.za google news results.
# 60 results of site lowvelder.co.za scraped successfully!
# Scraping page 7.0 of lowvelder.co.za google news results.
# 70 results of site lowvelder.co.za scraped successfully!
# Scraping page 8.0 of lowvelder.co.za google news results.
# 80 results of site lowvelder.co.za scraped successfully!
# Scraping page 9.0 of lowvelder.co.za google news results.
# 90 results of site lowvelder.co.za scraped successfully!
# Scraping page 10.0 of lowvelder.co.za google news results.
# 100 results of site lowvelder.co.za scraped successfully!
# Scraping page 11.0 of lowvelder.co.za google news results.
# 110 results of site lowvelder.co.za scraped successfully!
# Scraping page 12.0 of lowvelder.co.za google news results.
# 120 results of site lowvelder.co.za scraped successfully!
# Scraping page 13.0 of lowvelder.co.za google news results.
# 130 results of site lowvelder.co.za scraped successfully!
# Scraping page 14.0 of lowvelder.co.za google news results.
# 140 results of site lowvelder.co.za scraped successfully!
# Scraping page 15.0 of lowvelder.co.za google news results.
# 150 results of site lowvelder.co.za scraped successfully!
# Scraping page 16.0 of lowvelder.co.za google news results.
# 160 results of site lowvelder.co.za scraped successfully!
# Scraping page 17.0 of lowvelder.co.za google news results.
# 170 results of site lowvelder.co.za scraped successfully!
# Scraping page 18.0 of lowvelder.co.za google news results.
# 180 results of site lowvelder.co.za scraped successfully!
# Scraping page 19.0 of lowvelder.co.za google news results.
# 190 results of site lowvelder.co.za scraped successfully!
# Scraping page 20.0 of lowvelder.co.za google news results.
# 200 results of site lowvelder.co.za scraped successfully!
# Scraping page 21.0 of lowvelder.co.za google news results.
# 210 results of site lowvelder.co.za scraped successfully!
# Scraping page 22.0 of lowvelder.co.za google news results.
# 220 results of site lowvelder.co.za scraped successfully!
# Scraping page 23.0 of lowvelder.co.za google news results.
# 230 results of site lowvelder.co.za scraped successfully!
# Scraping page 24.0 of lowvelder.co.za google news results.
# 240 results of site lowvelder.co.za scraped successfully!
# Scraping page 25.0 of lowvelder.co.za google news results.
# 250 results of site lowvelder.co.za scraped successfully!
# Scraping page 26.0 of lowvelder.co.za google news results.
# 260 results of site lowvelder.co.za scraped successfully!
# Scraping page 27.0 of lowvelder.co.za google news results.
# 270 results of site lowvelder.co.za scraped successfully!
# Scraping page 28.0 of lowvelder.co.za google news results.
# 280 results of site lowvelder.co.za scraped successfully!
# Scraping page 29.0 of lowvelder.co.za google news results.
# Saved data from 278 articles of lowvelder.co.za to .csv!
# Scraping page 1.0 of zululandobserver.co.za google news results.
# 10 results of site zululandobserver.co.za scraped successfully!
# Scraping page 2.0 of zululandobserver.co.za google news results.
# 20 results of site zululandobserver.co.za scraped successfully!
# Scraping page 3.0 of zululandobserver.co.za google news results.
# 30 results of site zululandobserver.co.za scraped successfully!
# Scraping page 4.0 of zululandobserver.co.za google news results.
# 40 results of site zululandobserver.co.za scraped successfully!
# Scraping page 5.0 of zululandobserver.co.za google news results.
# 50 results of site zululandobserver.co.za scraped successfully!
# Scraping page 6.0 of zululandobserver.co.za google news results.
# 60 results of site zululandobserver.co.za scraped successfully!
# Scraping page 7.0 of zululandobserver.co.za google news results.
# 70 results of site zululandobserver.co.za scraped successfully!
# Scraping page 8.0 of zululandobserver.co.za google news results.
# 80 results of site zululandobserver.co.za scraped successfully!
# Scraping page 9.0 of zululandobserver.co.za google news results.
# 90 results of site zululandobserver.co.za scraped successfully!
# Scraping page 10.0 of zululandobserver.co.za google news results.
# 100 results of site zululandobserver.co.za scraped successfully!
# Scraping page 11.0 of zululandobserver.co.za google news results.
# 110 results of site zululandobserver.co.za scraped successfully!
# Scraping page 12.0 of zululandobserver.co.za google news results.
# 120 results of site zululandobserver.co.za scraped successfully!
# Scraping page 13.0 of zululandobserver.co.za google news results.
# 130 results of site zululandobserver.co.za scraped successfully!
# Scraping page 14.0 of zululandobserver.co.za google news results.
# 140 results of site zululandobserver.co.za scraped successfully!
# Scraping page 15.0 of zululandobserver.co.za google news results.
# 150 results of site zululandobserver.co.za scraped successfully!
# Scraping page 16.0 of zululandobserver.co.za google news results.
# 160 results of site zululandobserver.co.za scraped successfully!
# Scraping page 17.0 of zululandobserver.co.za google news results.
# 170 results of site zululandobserver.co.za scraped successfully!
# Scraping page 18.0 of zululandobserver.co.za google news results.
# 180 results of site zululandobserver.co.za scraped successfully!
# Scraping page 19.0 of zululandobserver.co.za google news results.
# 190 results of site zululandobserver.co.za scraped successfully!
# Scraping page 20.0 of zululandobserver.co.za google news results.
# 200 results of site zululandobserver.co.za scraped successfully!
# Scraping page 21.0 of zululandobserver.co.za google news results.
# 210 results of site zululandobserver.co.za scraped successfully!
# Scraping page 22.0 of zululandobserver.co.za google news results.
# 220 results of site zululandobserver.co.za scraped successfully!
# Scraping page 23.0 of zululandobserver.co.za google news results.
# 230 results of site zululandobserver.co.za scraped successfully!
# Scraping page 24.0 of zululandobserver.co.za google news results.
# 240 results of site zululandobserver.co.za scraped successfully!
# Scraping page 25.0 of zululandobserver.co.za google news results.
# 250 results of site zululandobserver.co.za scraped successfully!
# Scraping page 26.0 of zululandobserver.co.za google news results.
# 260 results of site zululandobserver.co.za scraped successfully!
# Scraping page 27.0 of zululandobserver.co.za google news results.
# 270 results of site zululandobserver.co.za scraped successfully!
# Scraping page 28.0 of zululandobserver.co.za google news results.
# 280 results of site zululandobserver.co.za scraped successfully!
# Scraping page 29.0 of zululandobserver.co.za google news results.
# Saved data from 271 articles of zululandobserver.co.za to .csv!
# Scraping page 1.0 of ziwaphi.com google news results.
# 10 results of site ziwaphi.com scraped successfully!
# Scraping page 2.0 of ziwaphi.com google news results.
# 20 results of site ziwaphi.com scraped successfully!
# Scraping page 3.0 of ziwaphi.com google news results.
# 30 results of site ziwaphi.com scraped successfully!
# Scraping page 4.0 of ziwaphi.com google news results.
# 40 results of site ziwaphi.com scraped successfully!
# Scraping page 5.0 of ziwaphi.com google news results.
# 50 results of site ziwaphi.com scraped successfully!
# Scraping page 6.0 of ziwaphi.com google news results.
# 60 results of site ziwaphi.com scraped successfully!
# Scraping page 7.0 of ziwaphi.com google news results.
# 70 results of site ziwaphi.com scraped successfully!
# Scraping page 8.0 of ziwaphi.com google news results.
# 80 results of site ziwaphi.com scraped successfully!
# Scraping page 9.0 of ziwaphi.com google news results.
# 90 results of site ziwaphi.com scraped successfully!
# Scraping page 10.0 of ziwaphi.com google news results.
# 100 results of site ziwaphi.com scraped successfully!
# Scraping page 11.0 of ziwaphi.com google news results.
# 110 results of site ziwaphi.com scraped successfully!
# Scraping page 12.0 of ziwaphi.com google news results.
# 120 results of site ziwaphi.com scraped successfully!
# Scraping page 13.0 of ziwaphi.com google news results.
# Saved data from 115 articles of ziwaphi.com to .csv!
# Scrape complete!

# %%
headlines_dict = {"url": urls, "headline": headlines,  "subtitle": subtitles, "time": times, "scrape_date": scrape_dates, "site": websites}
# df of results
headlines_df = pd.DataFrame.from_dict(headlines_dict)
number_of_articles = len(headlines_df)
# save results to csv
headlines_df.to_csv(f'../data/{number_of_articles}_{site}_articles.csv')

# %%
list(SA.site.unique().flatten())[12:]
# Out:
# ['Dailymaverick.co.za',
#  'Vodacom.co.za',
#  'Sowetanlive.co.za',
#  'mg.co.za',
#  'MyBroadband.co.za',
#  'Moneyweb.co.za',
#  'Businesslive.co.za',
#  'Enca.com',
#  'Capetownetc.com',
#  'iol.co.za',
#  'heraldlive.co.za',
#  'dispatchlive.co.za',
#  'dailysun.co.za',
#  'cbn.co.za',
#  'lowvelder.co.za',
#  'zululandobserver.co.za',
#  'ziwaphi.com']

# %%
# Out:
# []

# %%
coverpage_news[i].a['href'][7:]
# Out:
# 'https://www.theblaze.com/news/leftist-woman-spits-in-face-of-cop&sa=U&ved=2ahUKEwj_2pujuo7tAhUMI6wKHaZdAtUQxfQBMAl6BAgCEAE&usg=AOvVaw2TSZgMP4nTF5XNFsvmKzCh'

# %%
coverpage_news = soup1.find_all('div', class_='ZINbbc xpd O9g5cc uUPGi')
# coverpage_news = soup1.find_all('div', class_='kCrYT')

# %%
site = random.choice(sites)

# %%
headlines_dict = {"url": [url], "headline": [headline],  "subtitle": [subtitle], "time": [time], "scrape_date": [scrape_date], "site":[site]}
headlines_df = pd.DataFrame.from_dict(headlines_dict)
number_of_articles = len(headlines_df)
headlines_df.to_csv(f'../data/{number_of_articles}_articles.csv')

# %%
print(headline)
print(url)
print(time)
print(subtitle)
print(scrape_date)
# Out:
# 19-year-old woman ends life in UP''s Bulandshahr, blames three men in suicide noteOutlook India
# https://www.outlookindia.com/newsscroll/19yearold-woman-ends-life-in-ups-bulandshahr-blames-three-men-in-suicide-note/1977017&sa=U&ved=2ahUKEwiM16CdxY7tAhVDXawKHd_cBnU4ChDF9AEwB3oECAAQAQ&usg=AOvVaw1n2cj0aRpqzPcYPDnrIMth
# 2 giorni fa
# Bulandshahr (UP), Nov 16 (PTI) A 19-year-old woman allegedly died by suicide in a ... She left behind a suicide note blaming three people for her death. ... and statement) of the CrPC, the girl completely denied the incident
# 19/11/2020

# %%
# print(soup1.prettify())
i = 7
url = coverpage_news[i].a['href'][7:]
headline = coverpage_news[i].a.text
time = coverpage_news[i].span.text
subtitle = coverpage_news[i].text.split('�')[1].strip().strip('"').strip('.')
scrape_date = datetime.datetime.now().strftime("%d/%m/%Y")
